# %%
import numpy as np
import scipy.special as sp
import matplotlib.pyplot as plt

# %% [markdown]
# iii) Plot the length distribution for L = 2 and k = 1, 2, 3, 4, 5

# %%
L = 2
final_list = []
#iterate over different values of k
for k in [1,2,3,4,5]:
    y_list = []
    #iterate over different values of l
    for l in range(0,30):   
        y = (1 / sp.gamma(k)) * ( np.exp(-l/L) / L ) * ( (l/L)**(k-1) )
        y_list.append(y)
    final_list.append(y_list)

# %%
#plot figure
plt.figure(figsize=(7,5))
labels = ['k = 1', 'k = 2', 'k = 3', 'k = 4', 'k = 5']
for i,j in zip(final_list, labels):
    plt.plot(i, label = j)
    plt.legend()
plt.xlabel('l')
plt.ylabel('P(l)')
plt.title('Length distribution for L = 2 and k = 1,2,3,4,5')
plt.show()
